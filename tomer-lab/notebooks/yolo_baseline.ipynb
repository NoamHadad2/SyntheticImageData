# %%
from __future__ import annotations

import matplotlib.pyplot as plt
from pathlib import Path
from IPython.display import display
import numpy as np
import pandas as pd
import random
from ultralytics import YOLO

# %%
ROOT = Path.cwd().parents[0]
print("Project root:", ROOT)

DEFAULT_IMG_DIR = (
    ROOT / "data" / "subset_100" / "aug1_animals" / "images"
)
IMAGE_EXTS = {".png", ".jpg", ".jpeg", ".bmp"}


def list_images(folder: Path) -> list[Path]:
    if not folder.exists():
        raise FileNotFoundError(f"Images folder not found: {folder}")
    imgs = sorted([p for p in folder.iterdir() if p.suffix.lower() in IMAGE_EXTS])
    if not imgs:
        raise RuntimeError(f"No images found in {folder}")
    return imgs
# Out:
# Project root: /Users/tomeratia/Desktop/לימודים/תואר ראשון/שנה ג/GEN AI project/Autonomous_Project

# %%
model = YOLO(ROOT / "yolov8s.pt")
images = list_images(DEFAULT_IMG_DIR)
print(f"Found {len(images)} images in {DEFAULT_IMG_DIR}")

animal_classes = {
    "dog",
    "deer",
    "wolf",
    "cat",
    "fox",
}

results = model(images, conf=0.25)
rows: list[dict] = []

images_with_animals = 0
all_confidences: list[float] = []
detections_per_image: list[int] = []

for img_path, r in zip(images, results):
    animal_confs: list[float] = []

    for box in r.boxes:
        cls_name = model.names[int(box.cls[0])]
        if cls_name in animal_classes:
            conf = float(box.conf[0])
            animal_confs.append(conf)
            all_confidences.append(conf)

    has_animal = len(animal_confs) > 0
    if has_animal:
        images_with_animals += 1

    detections_per_image.append(len(animal_confs))

    rows.append({
        "image_name": img_path.name,
        "has_animal": has_animal,
        "num_animals": len(animal_confs),
        "avg_animal_conf": float(np.mean(animal_confs)) if animal_confs else np.nan,
        "detected_animals": [
            model.names[int(box.cls[0])]
            for box in r.boxes
            if model.names[int(box.cls[0])] in animal_classes
        ],
    })

detection_rate = images_with_animals / len(images)
avg_confidence = float(np.mean(all_confidences)) if all_confidences else 0.0
avg_detections = float(np.mean(detections_per_image)) if detections_per_image else 0.0

df = pd.DataFrame(rows)
# Out:
# Found 89 images in /Users/tomeratia/Desktop/לימודים/תואר ראשון/שנה ג/GEN AI project/Autonomous_Project/data/subset_100/aug1_animals/images
#
# 0: 640x640 1 car, 1 horse, 170.7ms
# 1: 640x640 1 car, 6 traffic lights, 1 stop sign, 1 dog, 170.7ms
# 2: 640x640 4 persons, 6 cars, 170.7ms
# 3: 640x640 3 cars, 170.7ms
# 4: 640x640 5 cars, 1 motorcycle, 1 truck, 170.7ms
# 5: 640x640 9 cars, 1 traffic light, 1 stop sign, 170.7ms
# 6: 640x640 9 cars, 1 traffic light, 1 stop sign, 2 dogs, 170.7ms
# 7: 640x640 1 person, 2 cars, 1 traffic light, 170.7ms
# 8: 640x640 6 cars, 1 bench, 1 cat, 170.7ms
# 9: 640x640 3 cars, 1 traffic light, 1 bird, 1 dog, 170.7ms
# 10: 640x640 3 persons, 2 cars, 1 traffic light, 170.7ms
# 11: 640x640 2 persons, 1 car, 170.7ms
# 12: 640x640 3 persons, 2 bicycles, 1 bench, 1 dog, 170.7ms
# 13: 640x640 1 person, 3 cars, 1 dog, 170.7ms
# 14: 640x640 2 persons, 3 bicycles, 2 cars, 1 traffic light, 1 dog, 170.7ms
# 15: 640x640 3 persons, 3 bicycles, 3 cars, 1 traffic light, 1 dog, 170.7ms
# 16: 640x640 6 cars, 1 bus, 1 truck, 1 dog, 1 tv, 170.7ms
# 17: 640x640 2 persons, 1 car, 1 truck, 1 dog, 170.7ms
# 18: 640x640 9 cars, 1 truck, 170.7ms
# 19: 640x640 1 car, 170.7ms
# 20: 640x640 14 cars, 1 cat, 170.7ms
# 21: 640x640 3 bicycles, 4 cars, 170.7ms
# 22: 640x640 1 car, 1 bird, 170.7ms
# 23: 640x640 3 cars, 1 bench, 170.7ms
# 24: 640x640 1 person, 2 cars, 1 motorcycle, 1 dog, 170.7ms
# 25: 640x640 3 cars, 1 stop sign, 1 bird, 1 cat, 170.7ms
# 26: 640x640 1 person, 2 cars, 1 stop sign, 170.7ms
# 27: 640x640 4 persons, 2 cars, 1 stop sign, 170.7ms
# 28: 640x640 (no detections), 170.7ms
# 29: 640x640 1 car, 170.7ms
# 30: 640x640 12 cars, 1 dog, 170.7ms
# 31: 640x640 22 cars, 1 dog, 170.7ms
# 32: 640x640 1 car, 1 dog, 170.7ms
# 33: 640x640 1 person, 6 cars, 170.7ms
# 34: 640x640 5 cars, 1 dog, 1 cow, 170.7ms
# 35: 640x640 3 cars, 170.7ms
# 36: 640x640 1 person, 5 cars, 1 dog, 170.7ms
# 37: 640x640 7 cars, 1 bus, 1 truck, 1 traffic light, 170.7ms
# 38: 640x640 1 person, 1 car, 1 dog, 170.7ms
# 39: 640x640 1 car, 5 traffic lights, 1 dog, 170.7ms
# 40: 640x640 5 cars, 1 dog, 1 frisbee, 170.7ms
# 41: 640x640 1 person, 4 cars, 1 bench, 1 dog, 170.7ms
# 42: 640x640 1 car, 1 bird, 170.7ms
# 43: 640x640 4 cars, 1 dog, 1 cow, 170.7ms
# 44: 640x640 1 person, 3 cars, 170.7ms
# 45: 640x640 5 persons, 3 cars, 2 benchs, 170.7ms
# 46: 640x640 3 persons, 3 cars, 1 bench, 2 horses, 170.7ms
# 47: 640x640 1 car, 170.7ms
# 48: 640x640 4 cars, 1 truck, 1 cow, 170.7ms
# 49: 640x640 3 cars, 1 bench, 170.7ms
# 50: 640x640 7 cars, 6 traffic lights, 1 dog, 170.7ms
# 51: 640x640 8 cars, 1 dog, 170.7ms
# 52: 640x640 11 cars, 2 trucks, 170.7ms
# 53: 640x640 2 persons, 1 bicycle, 3 cars, 1 stop sign, 1 dog, 170.7ms
# 54: 640x640 8 cars, 1 traffic light, 170.7ms
# 55: 640x640 8 persons, 4 cars, 1 motorcycle, 1 skateboard, 170.7ms
# 56: 640x640 1 car, 1 truck, 170.7ms
# 57: 640x640 2 cars, 1 bench, 170.7ms
# 58: 640x640 5 cars, 1 motorcycle, 2 trucks, 1 dog, 170.7ms
# 59: 640x640 6 cars, 1 stop sign, 1 dog, 170.7ms
# 60: 640x640 6 cars, 1 stop sign, 170.7ms
# 61: 640x640 6 cars, 170.7ms
# 62: 640x640 9 cars, 170.7ms
# 63: 640x640 2 cars, 1 dog, 170.7ms
# 64: 640x640 11 cars, 1 motorcycle, 1 truck, 170.7ms
# 65: 640x640 1 person, 4 cars, 170.7ms
# 66: 640x640 1 person, 5 cars, 4 traffic lights, 1 dog, 170.7ms
# 67: 640x640 1 person, 1 bus, 1 boat, 2 stop signs, 1 handbag, 170.7ms
# 68: 640x640 3 cars, 170.7ms
# 69: 640x640 1 car, 1 train, 1 dog, 170.7ms
# 70: 640x640 2 persons, 3 cars, 1 motorcycle, 1 dog, 1 sports ball, 170.7ms
# 71: 640x640 1 person, 7 cars, 1 dog, 170.7ms
# 72: 640x640 1 dog, 1 bear, 170.7ms
# 73: 640x640 6 cars, 1 cow, 170.7ms
# 74: 640x640 1 person, 1 car, 1 bird, 1 dog, 170.7ms
# 75: 640x640 3 persons, 3 cars, 1 motorcycle, 2 benchs, 1 dog, 170.7ms
# 76: 640x640 9 cars, 1 dog, 170.7ms
# 77: 640x640 1 stop sign, 1 dog, 170.7ms
# 78: 640x640 3 cars, 170.7ms
# 79: 640x640 2 cars, 1 truck, 2 traffic lights, 170.7ms
# 80: 640x640 1 person, 1 dog, 170.7ms
# 81: 640x640 1 car, 170.7ms
# 82: 640x640 1 car, 170.7ms
# 83: 640x640 2 cars, 6 traffic lights, 1 stop sign, 1 dog, 170.7ms
# 84: 640x640 7 cars, 1 bench, 170.7ms
# 85: 640x640 5 cars, 1 truck, 1 dog, 170.7ms
# 86: 640x640 1 person, 170.7ms
# 87: 640x640 7 persons, 3 cars, 1 bench, 1 horse, 170.7ms
# 88: 640x640 1 car, 6 traffic lights, 1 stop sign, 1 dog, 170.7ms
# Speed: 1.9ms preprocess, 170.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)

# %%
idxs = df.index[df["has_animal"] == True].tolist()
idx = random.choice(idxs) if idxs else 0

img_path = images[idx]
r = results[idx]

annotated = r.plot()  # numpy array (BGR)

plt.figure(figsize=(12, 6))
plt.title(f"YOLO detections | {img_path.name}")
plt.imshow(annotated[..., ::-1])  # BGR -> RGB
plt.axis("off")
plt.show()

# %%
print("\n=== Baseline Metrics ===")
print(f"Detection rate: {detection_rate:.3f}")
print(f"Average confidence: {avg_confidence:.3f}")
print(f"Avg detections per image: {avg_detections:.2f}")

display(df)

print("\n=== Data Summary ===")
print("Images with animals:", df["has_animal"].sum())
print("Images without animals:", (~df["has_animal"]).sum())
# Out:
# === Baseline Metrics ===
# Detection rate: 0.472
# Average confidence: 0.705
# Avg detections per image: 0.48
#                                 image_name  has_animal  num_animals  \
# 0       000004_deer_three_quarter_view.png       False            0
# 1               000015_fox_from_behind.png        True            1
# 2     000080_medium-size_dog_side_view.png       False            0
# 3               000105_wolf_front_view.png       False            0
# 4       000128_wolf_three_quarter_view.png       False            0
# ..                                     ...         ...          ...
# 84                001732_fox_side_view.png       False            0
# 85                001735_fox_low_angle.png        True            1
# 86        001780_cat_slightly_top_down.png       False            0
# 87  001784_medium-size_dog_from_behind.png       False            0
# 88                001868_fox_low_angle.png        True            1
#
#     avg_animal_conf detected_animals
# 0               NaN               []
# 1          0.773883            [dog]
# 2               NaN               []
# 3               NaN               []
# 4               NaN               []
# ..              ...              ...
# 84              NaN               []
# 85         0.681474            [dog]
# 86              NaN               []
# 87              NaN               []
# 88         0.426763            [dog]
#
# [89 rows x 5 columns]
# === Data Summary ===
# Images with animals: 42
# Images without animals: 47
