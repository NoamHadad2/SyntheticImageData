# %%
# !pip install ultralytics -q
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
from PIL import Image

model = YOLO('/content/best.pt')

results = model('/content/31439_tumb_800X480.jpg')

res_plotted = results[0].plot()
plt.figure(figsize=(12, 8))
plt.imshow(cv2.cvtColor(res_plotted, cv2.COLOR_BGR2RGB))
plt.title("YOLO Detection - Pedestrians and Road Users")
plt.axis('off')
plt.show()

for box in results[0].boxes:
    print(f"Detected: {model.names[int(box.cls[0])]} with confidence {box.conf[0]:.2f}")
# Out:
# image 1/1 /content/31439_tumb_800X480.jpg: 320x512 1 crosswalk, 664.5ms
# Speed: 1.9ms preprocess, 664.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 512)
# Detected: crosswalk with confidence 0.27
